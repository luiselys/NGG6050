# %% [markdown]
# <a href="https://colab.research.google.com/github/luiselys/NGG6050/blob/main/QNC_Presentation_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import pandas as pd


# Ct values for NRTN
control_gene1 = [1, 1.5, 1.4, 1.3, 1.2, 1.9, 1.3, 1.3]
glaucoma_gene1 = [1.8, 2.9, 1.8, 2.9, 1.6, 2.3, 2.7, 1.6, 1.4, 1.1, ]
controlAAVSIRT1_gene1 = [4.2, 3.4, 2.6, 3.3, 3.0, 2.7, 4.0, 2.6]
glaucomaAAVSIRT1_gene1 = [3.4, 3.4, 4.1, 3.9, 4.8, 3.2, 4.1, 4.0, 4.5, 3.8]

# Ct values for LilBr
control_gene2 = [3, 4, 5]
disease_gene2 = [20, 18, 19]
controlAAVSIRT1_gene2 = []
glaucomaAAVSIRT1_gene2 = []

# Ct values for Steap4
control_gene3 = [3, 4, 5]
disease_gene3 = [20, 18, 19]
controlAAVSIRT1_gene3 = []
glaucomaAAVSIRT1_gene3 = []

# Ct values for Sox1
control_gene4 = [3, 4, 5]
disease_gene4 = [20, 18, 19]
controlAAVSIRT1_gene4 = []
glaucomaAAVSIRT1_gene4 = []

# Ct values for Wnt7a
control_gene5 = [3, 4, 5]
disease_gene5 = [20, 18, 19]
controlAAVSIRT1_gene5 = []
glaucomaAAVSIRT1_gene5 = []

# Ct values for Elf3
control_gene6 = [3, 4, 5]
disease_gene6 = [20, 18, 19]
controlAAVSIRT1_gene6 = []
glaucomaAAVSIRT1_gene6 = []

#genes = pd.read_csv()

# Create a box plot for gene 1
plt.subplot(1, 2, 1)  # Create a subplot for gene 1
plt.boxplot([control_gene1, glaucoma_gene1,controlAAVSIRT1_gene1, glaucomaAAVSIRT1_gene1 ], labels=['Control', 'Glaucoma', 'Control + AAV SIRT1', 'Glaucoma + AAV SIRT1'])
plt.title('NRTN Relative Fold Change')
plt.ylabel('Relative Fold Change')
plt.xticks(rotation=45, ha='center')


# Create a box plot for gene 2
plt.subplot(1, 2, 2)  # Create a subplot for gene 2
plt.boxplot([control_gene2, disease_gene2], labels=['Control', 'Disease'])
plt.title('Gene 2 Ct Values')
plt.ylabel('Ct Values')

plt.tight_layout()  # Ensure proper spacing between subplots
plt.show()

# %%
import matplotlib.pyplot as plt

# Sample data
control_gene1 = [1, 1.5, 1.4, 1.3, 1.2, 1.9, 1.3, 1.3]
glaucoma_gene1 = [1.8, 2.9, 1.8, 2.9, 1.6, 2.3, 2.7, 1.6, 1.4, 1.1]
controlAAVSIRT1_gene1 = [4.2, 3.4, 2.6, 3.3, 3.0, 2.7, 4.0, 2.6]
glaucomaAAVSIRT1_gene1 = [3.4, 3.4, 4.1, 3.9, 4.8, 3.2, 4.1, 4.0, 4.5, 3.8]

# Create a box plot for gene 1
plt.figure(figsize=(5, 5))  # Adjust the figure size as needed
plt.boxplot(
    [control_gene1, glaucoma_gene1, controlAAVSIRT1_gene1, glaucomaAAVSIRT1_gene1],
    labels=['Control', 'Glaucoma', 'Control + AAV SIRT1', 'Glaucoma + AAV SIRT1']
)

# Customize the x-axis labels to center them under the ticks
x_positions = [1, 2, 3, 4]  # Adjust these positions as needed
x_labels = ['Control', 'Glaucoma', 'Control + AAV SIRT1', 'Glaucoma + AAV SIRT1']  # Corresponding labels

plt.xticks(x_positions, x_labels, rotation=45, ha='center')

plt.title('NRTN Relative Fold Change')
plt.ylabel('Relative Fold Change')
plt.tight_layout()  # Ensure proper spacing between subplots
plt.show()
